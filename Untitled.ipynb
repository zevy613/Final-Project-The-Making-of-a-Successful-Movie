# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

df2000 = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
df2001 = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')

display(df2000)
display(df2001)
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 1195  tt6174238    0.0                               NaN
# 1196  tt7029820    0.0                               NaN
# 1197  tt7197642    0.0                               NaN
# 1198  tt7631368    0.0  /sF0gUHE0YzZNXYugTB2LFxJIppf.jpg
# 1199  tt7802790    0.0  /etxml2M8GQzb31jcH0cdA489WCX.jpg
#
#                                   belongs_to_collection      budget  \
# 0                                                   NaN         NaN
# 1                                                   NaN  10000000.0
# 2                                                   NaN         0.0
# 3                                                   NaN         0.0
# 4                                                   NaN    150000.0
# ...                                                 ...         ...
# 1195  {'id': 404302, 'name': 'Cold War Collection', ...         0.0
# 1196                                                NaN         0.0
# 1197                                                NaN         0.0
# 1198                                                NaN  10000000.0
# 1199                                                NaN         0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2              [{'id': 878, 'name': 'Science Fiction'}]
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# ...                                                 ...
# 1195                      [{'id': 80, 'name': 'Crime'}]
# 1196                                                 []
# 1197                     [{'id': 35, 'name': 'Comedy'}]
# 1198                     [{'id': 27, 'name': 'Horror'}]
# 1199  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
#
#                                   homepage        id original_language  \
# 0                                      NaN       NaN               NaN
# 1                                      NaN   62127.0                en
# 2                                      NaN  110977.0                en
# 3                                      NaN  442869.0                hi
# 4     http://www.wkw-inthemoodforlove.com/     843.0                cn
# ...                                    ...       ...               ...
# 1195                                   NaN  223878.0                cn
# 1196                                   NaN  604889.0                en
# 1197                                   NaN  872676.0                en
# 1198                                   NaN   97186.0                fr
# 1199                                   NaN  610992.0                fa
#
#                original_title  ...     revenue  runtime  \
# 0                         NaN  ...         NaN      NaN
# 1             The Fantasticks  ...         0.0     86.0
# 2               For the Cause  ...         0.0    100.0
# 3                        Gang  ...         0.0    152.0
# 4                        花樣年華  ...  12854953.0     99.0
# ...                       ...  ...         ...      ...
# 1195                       冷战  ...         0.0      0.0
# 1196     Scream For Christmas  ...         0.0     80.0
# 1197  Goodbye, Merry-Go-Round  ...         0.0     90.0
# 1198               I, Vampire  ...         0.0     85.0
# 1199                مومیایی ۳  ...         0.0     98.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4     [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# ...                                                 ...       ...
# 1195  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 1196                                                 []  Released
# 1197                                                 []  Released
# 1198  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1199  [{'english_name': 'Persian', 'iso_639_1': 'fa'...  Released
#
#                                                 tagline  \
# 0                                                   NaN
# 1         Try to remember the first time magic happened
# 2          The ultimate showdown on a forbidden planet.
# 3                                                   NaN
# 4     Feel the heat, keep the feeling burning, let t...
# ...                                                 ...
# 1195                                                NaN
# 1196                                                NaN
# 1197                                                NaN
# 1198                                                NaN
# 1199                                                NaN
#
#                         title  video  vote_average vote_count certification
# 0                         NaN    NaN           NaN        NaN           NaN
# 1             The Fantasticks    0.0         5.500       22.0           NaN
# 2               For the Cause    0.0         5.100        8.0           NaN
# 3                        Gang    0.0         4.000        1.0           NaN
# 4        In the Mood for Love    0.0         8.112     2009.0            PG
# ...                       ...    ...           ...        ...           ...
# 1195                 Cold War    0.0         2.000        2.0           NaN
# 1196     Scream For Christmas    0.0         0.000        0.0           NaN
# 1197  Goodbye, Merry-Go-Round    0.0         0.000        0.0           NaN
# 1198               I, Vampire    0.0         6.400        4.0            NR
# 1199              The Mummy 3    0.0         7.000        1.0           NaN
#
# [1200 rows x 26 columns]
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 1195  tt6174238    0.0                               NaN
# 1196  tt7029820    0.0                               NaN
# 1197  tt7197642    0.0                               NaN
# 1198  tt7631368    0.0  /sF0gUHE0YzZNXYugTB2LFxJIppf.jpg
# 1199  tt7802790    0.0  /etxml2M8GQzb31jcH0cdA489WCX.jpg
#
#                                   belongs_to_collection      budget  \
# 0                                                   NaN         NaN
# 1                                                   NaN  10000000.0
# 2                                                   NaN         0.0
# 3                                                   NaN         0.0
# 4                                                   NaN    150000.0
# ...                                                 ...         ...
# 1195  {'id': 404302, 'name': 'Cold War Collection', ...         0.0
# 1196                                                NaN         0.0
# 1197                                                NaN         0.0
# 1198                                                NaN  10000000.0
# 1199                                                NaN         0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2              [{'id': 878, 'name': 'Science Fiction'}]
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# ...                                                 ...
# 1195                      [{'id': 80, 'name': 'Crime'}]
# 1196                                                 []
# 1197                     [{'id': 35, 'name': 'Comedy'}]
# 1198                     [{'id': 27, 'name': 'Horror'}]
# 1199  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
#
#                                   homepage        id original_language  \
# 0                                      NaN       NaN               NaN
# 1                                      NaN   62127.0                en
# 2                                      NaN  110977.0                en
# 3                                      NaN  442869.0                hi
# 4     http://www.wkw-inthemoodforlove.com/     843.0                cn
# ...                                    ...       ...               ...
# 1195                                   NaN  223878.0                cn
# 1196                                   NaN  604889.0                en
# 1197                                   NaN  872676.0                en
# 1198                                   NaN   97186.0                fr
# 1199                                   NaN  610992.0                fa
#
#                original_title  ...     revenue  runtime  \
# 0                         NaN  ...         NaN      NaN
# 1             The Fantasticks  ...         0.0     86.0
# 2               For the Cause  ...         0.0    100.0
# 3                        Gang  ...         0.0    152.0
# 4                        花樣年華  ...  12854953.0     99.0
# ...                       ...  ...         ...      ...
# 1195                       冷战  ...         0.0      0.0
# 1196     Scream For Christmas  ...         0.0     80.0
# 1197  Goodbye, Merry-Go-Round  ...         0.0     90.0
# 1198               I, Vampire  ...         0.0     85.0
# 1199                مومیایی ۳  ...         0.0     98.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4     [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# ...                                                 ...       ...
# 1195  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 1196                                                 []  Released
# 1197                                                 []  Released
# 1198  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1199  [{'english_name': 'Persian', 'iso_639_1': 'fa'...  Released
#
#                                                 tagline  \
# 0                                                   NaN
# 1         Try to remember the first time magic happened
# 2          The ultimate showdown on a forbidden planet.
# 3                                                   NaN
# 4     Feel the heat, keep the feeling burning, let t...
# ...                                                 ...
# 1195                                                NaN
# 1196                                                NaN
# 1197                                                NaN
# 1198                                                NaN
# 1199                                                NaN
#
#                         title  video  vote_average vote_count certification
# 0                         NaN    NaN           NaN        NaN           NaN
# 1             The Fantasticks    0.0         5.500       22.0           NaN
# 2               For the Cause    0.0         5.100        8.0           NaN
# 3                        Gang    0.0         4.000        1.0           NaN
# 4        In the Mood for Love    0.0         8.112     2009.0            PG
# ...                       ...    ...           ...        ...           ...
# 1195                 Cold War    0.0         2.000        2.0           NaN
# 1196     Scream For Christmas    0.0         0.000        0.0           NaN
# 1197  Goodbye, Merry-Go-Round    0.0         0.000        0.0           NaN
# 1198               I, Vampire    0.0         6.400        4.0            NR
# 1199              The Mummy 3    0.0         7.000        1.0           NaN
#
# [1200 rows x 26 columns]
